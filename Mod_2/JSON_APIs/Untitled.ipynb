# %%
import requests
import json

# %%
apikey = '38bd973306e31acafd271b4e8027c41e'

# %%
def call_tmdb(api_key):
    response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=38bd973306e31acafd271b4e8027c41e&language=en-US&sort_by=vote_average.desc&page=1&vote_count.gte=100')
    return response

# %%
x = call_tmdb(apikey)

# %%
x = x.json()

# %%
x['results']
# Out:
# [{'popularity': 18.134,
#   'vote_count': 2113,
#   'video': False,
#   'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#   'id': 19404,
#   'adult': False,
#   'backdrop_path': '/mMaxGuQKuH4WUHBwUNhJOetDYE9.jpg',
#   'original_language': 'hi',
#   'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'genre_ids': [35, 18, 10749],
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'vote_average': 8.9,
#   'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   'release_date': '1995-10-20'},
#  {'popularity': 35.852,
#   'vote_count': 13806,
#   'video': False,
#   'poster_path': '/9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg',
#   'id': 278,
# ...

# %%
x['results'][1]
# Out:
# {'popularity': 35.852,
#  'vote_count': 13806,
#  'video': False,
#  'poster_path': '/9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg',
#  'id': 278,
#  'adult': False,
#  'backdrop_path': '/j9XKiZrVeViAixVRzCta7h1VU9W.jpg',
#  'original_language': 'en',
#  'original_title': 'The Shawshank Redemption',
#  'genre_ids': [80, 18],
#  'title': 'The Shawshank Redemption',
#  'vote_average': 8.7,
#  'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#  'release_date': '1994-09-23'}

# %%
x['results'][2]
# Out:
# {'popularity': 4.711,
#  'id': 359364,
#  'video': False,
#  'vote_count': 161,
#  'vote_average': 8.6,
#  'title': 'Human',
#  'release_date': '2015-09-11',
#  'original_language': 'fr',
#  'original_title': 'Human',
#  'genre_ids': [99],
#  'backdrop_path': '/fPfSJpCDvTzLdX0FkwYAkiqB6IL.jpg',
#  'adult': False,
# ...

# %%
res = requests.get('https://api.themoviedb.org/3/movie/359364?api_key=38bd973306e31acafd271b4e8027c41e&language=en-US')

# %%
res.json()
# Out:
# {'adult': False,
#  'backdrop_path': '/fPfSJpCDvTzLdX0FkwYAkiqB6IL.jpg',
#  'belongs_to_collection': None,
#  'budget': 13000000,
#  'genres': [{'id': 99, 'name': 'Documentary'}],
#  'homepage': 'http://www.human-themovie.org/',
#  'id': 359364,
#  'imdb_id': 'tt3327994',
#  'original_language': 'fr',
#  'original_title': 'Human',
# ...
